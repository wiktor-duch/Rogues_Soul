# %% [markdown]
# # Experiment 1 Setup
#
# - Environemt is fixed with seed 4
# - Map is undiscovered
#
# General env_setup:
# - Num rooms: 3
# - Items: Souls (2), Health Potion (0-1), Enemies (Level 1, 1-2)
#
# Aims:
# The aim of this experiment is to check if the results from experiment 1 holds if we mainpulate the seed value.

# %%
# !pip install stable-baselines3[extra] --quiet
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Initialization Environment
# Initialization and setup of the custom environment

# %%
from env import RoguesSoulsEnv

env = RoguesSoulsEnv(max_steps=500)
env.set_seed(4)
env.set_mode(1)
# Needs resetting to apply above changes
state = env.reset()
env.render(mode='human')
# Out:
# ------------------------
#
#
#
#
#
#
#      |------|
#      |....*.|
#      |......+####
#      |.>...b|   #
#      |..$...| |-+--|
#      |------| |.*..|
#               |..$b|
#               |....|
#               |....|
#     |----|    |....|
#     |....|    |-+--|
#     |....|      #
#     |.@..+#######
#     |....|
#     |....|
#     |----|
#
#
#
#
# 		LEVEL: 1/1	  HP: 16 	SOULS: 0
# 		DEFENSE: 2	MAX HP: 16 	POWER: 4
# ------------------------

# %% [markdown]
# # Flattening the observation space
#
# Stable-baseline3 requires the obseration space to be a 1D vector for better policy optimisation.

# %%
from gym.wrappers import FlattenObservation
env = FlattenObservation(env)

# %% [markdown]
# # Initialization agent
# Agent will be based on stable-baselines3 DQN algorithm

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv

# Stop training when the model reaches the reward threshold
callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=140, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=callback_on_best, verbose=1)

env = DummyVecEnv([lambda: env])
model = DQN('MlpPolicy', env, verbose=1, exploration_fraction=0.3, tensorboard_log='./logs/ex2_0_v1')
# Out:
# Using cpu device

# %% [markdown]
# # Adding the necessary check function
# This function checks the average score from n episodes

# %%
def get_average(env, model, n:int = 100) -> int:
    total = 0
    for e in range(1, n+1):
        obs = env.reset()
        done = False
        score = 0

        while not done:
            action, _ = model.predict(obs)
            obs, reward, done, _ = env.step(action)
            score += reward
        total += score

    return total/n

# %% [markdown]
# # Training the agent
#
# The agent will be trained until its average performance is above 180.

# %%
# for i in range(5):
#     tot_steps = 25000
#     model.learn(total_timesteps = tot_steps, reset_num_timesteps=False)
#     avg = get_average(model, 25)
#     print(f'Total iterations: {(i+1)*tot_steps}; Average {avg}')
#     if avg > 100:
#         break
    
model.learn(total_timesteps = 800000, reset_num_timesteps=False, tb_log_name='first_run', callback=eval_callback)
avg = get_average(env, model, 25)
print(f'Average: {avg}')
# Out:
# Logging to ./logs/ex2_0_v1/first_run_0
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 189      |
# |    time_elapsed     | 10       |
# |    total timesteps  | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 241      |
# |    time_elapsed     | 16       |
# |    total timesteps  | 4000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 261      |
# |    time_elapsed     | 22       |
# |    total timesteps  | 6000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.968    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 275      |
# |    time_elapsed     | 28       |
# |    total timesteps  | 8000     |
# ----------------------------------
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Eval num_timesteps=10000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.96     |
# | time/               |          |
# |    total timesteps  | 10000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.96     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 227      |
# |    time_elapsed     | 43       |
# |    total timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 238      |
# |    time_elapsed     | 49       |
# |    total timesteps  | 11776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.945    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 248      |
# |    time_elapsed     | 55       |
# |    total timesteps  | 13776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.938    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 254      |
# |    time_elapsed     | 62       |
# |    total timesteps  | 15776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.93     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 259      |
# |    time_elapsed     | 68       |
# |    total timesteps  | 17776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.922    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 263      |
# |    time_elapsed     | 74       |
# |    total timesteps  | 19776    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.921    |
# | time/               |          |
# |    total timesteps  | 20000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.913    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 242      |
# |    time_elapsed     | 90       |
# |    total timesteps  | 22000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.905    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 247      |
# |    time_elapsed     | 97       |
# |    total timesteps  | 24000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.897    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 251      |
# |    time_elapsed     | 103      |
# |    total timesteps  | 26000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.889    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 256      |
# |    time_elapsed     | 109      |
# |    total timesteps  | 28000    |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.881    |
# | time/               |          |
# |    total timesteps  | 30000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.881    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 243      |
# |    time_elapsed     | 123      |
# |    total timesteps  | 30000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.873    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 247      |
# |    time_elapsed     | 129      |
# |    total timesteps  | 32000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.865    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 250      |
# |    time_elapsed     | 135      |
# |    total timesteps  | 34000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.857    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 253      |
# |    time_elapsed     | 141      |
# |    total timesteps  | 36000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.85     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 256      |
# |    time_elapsed     | 148      |
# |    total timesteps  | 38000    |
# ----------------------------------
# Eval num_timesteps=40000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.842    |
# | time/               |          |
# |    total timesteps  | 40000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.842    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 245      |
# |    time_elapsed     | 162      |
# |    total timesteps  | 40000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.834    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 248      |
# |    time_elapsed     | 169      |
# |    total timesteps  | 42000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.826    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 251      |
# |    time_elapsed     | 175      |
# |    total timesteps  | 44000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.818    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 253      |
# |    time_elapsed     | 181      |
# |    total timesteps  | 46000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.81     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 255      |
# |    time_elapsed     | 187      |
# |    total timesteps  | 48000    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.802    |
# | time/               |          |
# |    total timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.802    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 247      |
# |    time_elapsed     | 202      |
# |    total timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.794    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 248      |
# |    time_elapsed     | 209      |
# |    total timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00129  |
# |    n_updates        | 499      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.788    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 249      |
# |    time_elapsed     | 214      |
# |    total timesteps  | 53617    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.15     |
# |    n_updates        | 904      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.78     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 250      |
# |    time_elapsed     | 221      |
# |    total timesteps  | 55481    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 1370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.775    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 251      |
# |    time_elapsed     | 226      |
# |    total timesteps  | 56929    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 1732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.769    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 252      |
# |    time_elapsed     | 231      |
# |    total timesteps  | 58380    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 2094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.764    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 252      |
# |    time_elapsed     | 235      |
# |    total timesteps  | 59572    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 2392     |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.763    |
# | time/               |          |
# |    total timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00976  |
# |    n_updates        | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.76     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 245      |
# |    time_elapsed     | 247      |
# |    total timesteps  | 60676    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 2668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.755    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 246      |
# |    time_elapsed     | 251      |
# |    total timesteps  | 62012    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 3002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.75     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 247      |
# |    time_elapsed     | 256      |
# |    total timesteps  | 63268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 3316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.745    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 247      |
# |    time_elapsed     | 260      |
# |    total timesteps  | 64428    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00372  |
# |    n_updates        | 3606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.74     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 248      |
# |    time_elapsed     | 264      |
# |    total timesteps  | 65749    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 3937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.734    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 248      |
# |    time_elapsed     | 270      |
# |    total timesteps  | 67173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0097   |
# |    n_updates        | 4293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.73     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 249      |
# |    time_elapsed     | 274      |
# |    total timesteps  | 68332    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0036   |
# |    n_updates        | 4582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.723    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 250      |
# |    time_elapsed     | 279      |
# |    total timesteps  | 69869    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00826  |
# |    n_updates        | 4967     |
# ----------------------------------
# Eval num_timesteps=70000, episode_reward=-150.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -150     |
# | rollout/            |          |
# |    exploration rate | 0.723    |
# | time/               |          |
# |    total timesteps  | 70000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00997  |
# |    n_updates        | 4999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.719    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 243      |
# |    time_elapsed     | 291      |
# |    total timesteps  | 71013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 5253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.714    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 244      |
# |    time_elapsed     | 295      |
# |    total timesteps  | 72200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 5549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.707    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 245      |
# |    time_elapsed     | 301      |
# |    total timesteps  | 73977    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00488  |
# |    n_updates        | 5994     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.702    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 246      |
# |    time_elapsed     | 305      |
# |    total timesteps  | 75231    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 6307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.697    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 246      |
# |    time_elapsed     | 310      |
# |    total timesteps  | 76665    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 6666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.691    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 247      |
# |    time_elapsed     | 315      |
# |    total timesteps  | 78077    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 7019     |
# ----------------------------------
# Eval num_timesteps=80000, episode_reward=-141.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -141     |
# | rollout/            |          |
# |    exploration rate | 0.683    |
# | time/               |          |
# |    total timesteps  | 80000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 7499     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.681    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 242      |
# |    time_elapsed     | 331      |
# |    total timesteps  | 80500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00488  |
# |    n_updates        | 7624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.675    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 243      |
# |    time_elapsed     | 337      |
# |    total timesteps  | 82004    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00492  |
# |    n_updates        | 8000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.67     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 243      |
# |    time_elapsed     | 341      |
# |    total timesteps  | 83348    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 8336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.662    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 244      |
# |    time_elapsed     | 348      |
# |    total timesteps  | 85348    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 8836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.654    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 245      |
# |    time_elapsed     | 355      |
# |    total timesteps  | 87308    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 9326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.648    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 246      |
# |    time_elapsed     | 360      |
# |    total timesteps  | 88803    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00684  |
# |    n_updates        | 9700     |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=-141.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -141     |
# | rollout/            |          |
# |    exploration rate | 0.644    |
# | time/               |          |
# |    total timesteps  | 90000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 9999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.641    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 241      |
# |    time_elapsed     | 375      |
# |    total timesteps  | 90735    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 10183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.635    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 242      |
# |    time_elapsed     | 379      |
# |    total timesteps  | 92159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00235  |
# |    n_updates        | 10539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.628    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 243      |
# |    time_elapsed     | 385      |
# |    total timesteps  | 93967    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 10991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.62     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 244      |
# |    time_elapsed     | 392      |
# |    total timesteps  | 95938    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 11484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.612    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 245      |
# |    time_elapsed     | 398      |
# |    total timesteps  | 97938    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 11984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.606    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 246      |
# |    time_elapsed     | 404      |
# |    total timesteps  | 99547    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00853  |
# |    n_updates        | 12386    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-141.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -141     |
# | rollout/            |          |
# |    exploration rate | 0.604    |
# | time/               |          |
# |    total timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 12499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.599    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 242      |
# |    time_elapsed     | 417      |
# |    total timesteps  | 101225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 12806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.591    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 243      |
# |    time_elapsed     | 423      |
# |    total timesteps  | 103225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00551  |
# |    n_updates        | 13306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.585    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 244      |
# |    time_elapsed     | 429      |
# |    total timesteps  | 104834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00782  |
# |    n_updates        | 13708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.577    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 245      |
# |    time_elapsed     | 435      |
# |    total timesteps  | 106834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 14208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.569    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 246      |
# |    time_elapsed     | 442      |
# |    total timesteps  | 108834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00275  |
# |    n_updates        | 14708    |
# ----------------------------------
# Eval num_timesteps=110000, episode_reward=-85.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -85      |
# | rollout/            |          |
# |    exploration rate | 0.565    |
# | time/               |          |
# |    total timesteps  | 110000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 14999    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.562    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 243      |
# |    time_elapsed     | 454      |
# |    total timesteps  | 110585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 15146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.556    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 243      |
# |    time_elapsed     | 460      |
# |    total timesteps  | 112185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.3      |
# |    n_updates        | 15546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.548    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 244      |
# |    time_elapsed     | 466      |
# |    total timesteps  | 114185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0071   |
# |    n_updates        | 16046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.542    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 245      |
# |    time_elapsed     | 472      |
# |    total timesteps  | 115829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 16457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.534    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 246      |
# |    time_elapsed     | 478      |
# |    total timesteps  | 117829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0787   |
# |    n_updates        | 16957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.526    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 247      |
# |    time_elapsed     | 485      |
# |    total timesteps  | 119829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 17457    |
# ----------------------------------
# Eval num_timesteps=120000, episode_reward=-142.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -142     |
# | rollout/            |          |
# |    exploration rate | 0.525    |
# | time/               |          |
# |    total timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 17499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.518    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 243      |
# |    time_elapsed     | 499      |
# |    total timesteps  | 121736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00664  |
# |    n_updates        | 17933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.512    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 244      |
# |    time_elapsed     | 504      |
# |    total timesteps  | 123403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 18350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.504    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 245      |
# |    time_elapsed     | 511      |
# |    total timesteps  | 125403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00682  |
# |    n_updates        | 18850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.496    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 245      |
# |    time_elapsed     | 517      |
# |    total timesteps  | 127403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 19350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.488    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 246      |
# |    time_elapsed     | 524      |
# |    total timesteps  | 129403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 19850    |
# ----------------------------------
# Eval num_timesteps=130000, episode_reward=-86.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -86      |
# | rollout/            |          |
# |    exploration rate | 0.485    |
# | time/               |          |
# |    total timesteps  | 130000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 19999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.479    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 244      |
# |    time_elapsed     | 537      |
# |    total timesteps  | 131500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 20374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.472    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 245      |
# |    time_elapsed     | 544      |
# |    total timesteps  | 133500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 20874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.464    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 246      |
# |    time_elapsed     | 550      |
# |    total timesteps  | 135500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 21374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.456    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 246      |
# |    time_elapsed     | 557      |
# |    total timesteps  | 137500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 21874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.448    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 247      |
# |    time_elapsed     | 563      |
# |    total timesteps  | 139500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 22374    |
# ----------------------------------
# Eval num_timesteps=140000, episode_reward=-87.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -87      |
# | rollout/            |          |
# |    exploration rate | 0.446    |
# | time/               |          |
# |    total timesteps  | 140000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71     |
# |    n_updates        | 22499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.44     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 245      |
# |    time_elapsed     | 576      |
# |    total timesteps  | 141500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 22874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.432    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 245      |
# |    time_elapsed     | 583      |
# |    total timesteps  | 143500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 23374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.424    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 246      |
# |    time_elapsed     | 590      |
# |    total timesteps  | 145500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 23874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.416    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 247      |
# |    time_elapsed     | 596      |
# |    total timesteps  | 147500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 24374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.408    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 247      |
# |    time_elapsed     | 602      |
# |    total timesteps  | 149500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00819  |
# |    n_updates        | 24874    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=-91.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -91      |
# | rollout/            |          |
# |    exploration rate | 0.406    |
# | time/               |          |
# |    total timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 24999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.401    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 245      |
# |    time_elapsed     | 615      |
# |    total timesteps  | 151213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 25303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.394    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 246      |
# |    time_elapsed     | 622      |
# |    total timesteps  | 153213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.459    |
# |    n_updates        | 25803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.386    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 246      |
# |    time_elapsed     | 628      |
# |    total timesteps  | 155213   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 26303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 247      |
# |    time_elapsed     | 633      |
# |    total timesteps  | 156773   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.203    |
# |    n_updates        | 26693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.373    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 247      |
# |    time_elapsed     | 639      |
# |    total timesteps  | 158458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 27114    |
# ----------------------------------
# Eval num_timesteps=160000, episode_reward=-144.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -144     |
# | rollout/            |          |
# |    exploration rate | 0.367    |
# | time/               |          |
# |    total timesteps  | 160000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 27499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.365    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 245      |
# |    time_elapsed     | 653      |
# |    total timesteps  | 160500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.198    |
# |    n_updates        | 27624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.357    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 246      |
# |    time_elapsed     | 660      |
# |    total timesteps  | 162500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 28124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.349    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 246      |
# |    time_elapsed     | 666      |
# |    total timesteps  | 164500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 28624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.341    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 247      |
# |    time_elapsed     | 673      |
# |    total timesteps  | 166500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 29124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.333    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 247      |
# |    time_elapsed     | 679      |
# |    total timesteps  | 168429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0759   |
# |    n_updates        | 29607    |
# ----------------------------------
# Eval num_timesteps=170000, episode_reward=-91.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -91      |
# | rollout/            |          |
# |    exploration rate | 0.327    |
# | time/               |          |
# |    total timesteps  | 170000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 29999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.325    |
# ...
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 121      |
# |    time_elapsed     | 6125     |
# |    total timesteps  | 746536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 174133   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 122      |
# |    time_elapsed     | 6131     |
# |    total timesteps  | 748536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0626   |
# |    n_updates        | 174633   |
# ----------------------------------
# Eval num_timesteps=750000, episode_reward=-35.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -35      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 750000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 174999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 122      |
# |    time_elapsed     | 6144     |
# |    total timesteps  | 751000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 175249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 122      |
# |    time_elapsed     | 6150     |
# |    total timesteps  | 753000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.627    |
# |    n_updates        | 175749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 122      |
# |    time_elapsed     | 6156     |
# |    total timesteps  | 755000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 176249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 122      |
# |    time_elapsed     | 6162     |
# |    total timesteps  | 757000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0871   |
# |    n_updates        | 176749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 123      |
# |    time_elapsed     | 6168     |
# |    total timesteps  | 759000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.39     |
# |    n_updates        | 177249   |
# ----------------------------------
# Eval num_timesteps=760000, episode_reward=-89.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -89      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 760000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0786   |
# |    n_updates        | 177499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 123      |
# |    time_elapsed     | 6181     |
# |    total timesteps  | 761000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0719   |
# |    n_updates        | 177749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 123      |
# |    time_elapsed     | 6186     |
# |    total timesteps  | 762800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 178199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 123      |
# |    time_elapsed     | 6192     |
# |    total timesteps  | 764800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.718    |
# |    n_updates        | 178699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 123      |
# |    time_elapsed     | 6197     |
# |    total timesteps  | 766555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.169    |
# |    n_updates        | 179138   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 123      |
# |    time_elapsed     | 6203     |
# |    total timesteps  | 768413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 179603   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 124      |
# |    time_elapsed     | 6208     |
# |    total timesteps  | 769959   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0586   |
# |    n_updates        | 179989   |
# ----------------------------------
# Eval num_timesteps=770000, episode_reward=-35.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -35      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 770000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0983   |
# |    n_updates        | 179999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 124      |
# |    time_elapsed     | 6220     |
# |    total timesteps  | 772000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.25     |
# |    n_updates        | 180499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2124     |
# |    fps              | 124      |
# |    time_elapsed     | 6226     |
# |    total timesteps  | 774000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 180999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2128     |
# |    fps              | 124      |
# |    time_elapsed     | 6232     |
# |    total timesteps  | 776000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0827   |
# |    n_updates        | 181499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 124      |
# |    time_elapsed     | 6236     |
# |    total timesteps  | 777576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.239    |
# |    n_updates        | 181893   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 124      |
# |    time_elapsed     | 6242     |
# |    total timesteps  | 779576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.329    |
# |    n_updates        | 182393   |
# ----------------------------------
# Eval num_timesteps=780000, episode_reward=-35.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -35      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 780000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0584   |
# |    n_updates        | 182499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 124      |
# |    time_elapsed     | 6256     |
# |    total timesteps  | 782000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0658   |
# |    n_updates        | 182999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 125      |
# |    time_elapsed     | 6261     |
# |    total timesteps  | 783580   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 183394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 125      |
# |    time_elapsed     | 6266     |
# |    total timesteps  | 785127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.93     |
# |    n_updates        | 183781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 125      |
# |    time_elapsed     | 6271     |
# |    total timesteps  | 786673   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0896   |
# |    n_updates        | 184168   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 125      |
# |    time_elapsed     | 6277     |
# |    total timesteps  | 788673   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0977   |
# |    n_updates        | 184668   |
# ----------------------------------
# Eval num_timesteps=790000, episode_reward=-35.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -35      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 790000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.282    |
# |    n_updates        | 184999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 125      |
# |    time_elapsed     | 6292     |
# |    total timesteps  | 791000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.156    |
# |    n_updates        | 185249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 125      |
# |    time_elapsed     | 6298     |
# |    total timesteps  | 793000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.146    |
# |    n_updates        | 185749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 126      |
# |    time_elapsed     | 6304     |
# |    total timesteps  | 795000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 186249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 126      |
# |    time_elapsed     | 6310     |
# |    total timesteps  | 797000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.206    |
# |    n_updates        | 186749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 126      |
# |    time_elapsed     | 6317     |
# |    total timesteps  | 799000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 187249   |
# ----------------------------------
# Eval num_timesteps=800000, episode_reward=-35.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 500      |
# |    mean_reward      | -35      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 800000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.218    |
# |    n_updates        | 187499   |
# ----------------------------------
# Average: [-38.99929]

# %% [markdown]
# # Results

# %%
# import time
episodes = 20
print(f'TESTING MODEL ON {episodes} EPISODES\n')
for e in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
#         env.render()
#         input('[ENTER]')
#         time.sleep(1)
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    completed = info[0].get('Completed')
    print(f'Episode: {e}, Score: {score}, Completed: {completed}')
# Out:
# TESTING MODEL ON 20 EPISODES
#
# Episode: 1, Score: [-34.99926], Completed: False
# Episode: 2, Score: [-34.999268], Completed: False
# Episode: 3, Score: [-34.99926], Completed: False
# Episode: 4, Score: [-34.999268], Completed: False
# Episode: 5, Score: [-34.99926], Completed: False
# Episode: 6, Score: [-34.99926], Completed: False
# Episode: 7, Score: [-84.99959], Completed: False
# Episode: 8, Score: [-34.99926], Completed: False
# Episode: 9, Score: [169.50067], Completed: True
# Episode: 10, Score: [-34.99926], Completed: False
# Episode: 11, Score: [-34.99926], Completed: False
# Episode: 12, Score: [-34.99926], Completed: False
# Episode: 13, Score: [-34.99926], Completed: False
# Episode: 14, Score: [-34.99926], Completed: False
# Episode: 15, Score: [-34.999268], Completed: False
# Episode: 16, Score: [-34.99926], Completed: False
# Episode: 17, Score: [-34.99926], Completed: False
# Episode: 18, Score: [-34.99926], Completed: False
# Episode: 19, Score: [-34.99926], Completed: False
# Episode: 20, Score: [-34.99926], Completed: False

# %%
## Continue training
# del model
# model = DQN.load('./models/experiment_1/ex7_1')
# model.learn(total_timesteps = 100000, reset_num_timesteps=False, tb_log_name='second_run')

# %%
# # Save model
# model.save('./models/experiment_1/ex12_v2')
